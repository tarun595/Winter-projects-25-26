# %% [markdown]
# # Assignment 4

# %% [markdown]
# ## A bit of info before you start.
#
#
# > ***First and foremost, dont use AI to code. Use it to understand and then write code yourself. Use AI to verify if the code you wrote it correct, that will help you learn far far more.***
#
# > ***Implement Stuff from sratch. Use cv2 functions only when numpy implementation can be extremely tedious.***
#
#
#
# You will need to use your own image for this assignment, which you need to import into here.
# If you cant fetch your image from any APIs that dont need credentials, then :
# To preserve an image in Google Colab without a continuous runtime or using Google Drive, you can use base64 string encoding of images ( its really simple )
#
# First, begin by normally uploading the image into the contents folders as you normally do in colab or fetch it using Drive or any API.
#
# To get the base64 string :
# ```
# import base64
# with open("your_image.jpg", "rb") as img_file:
#     print(base64.b64encode(img_file.read()).decode())
# ```
#
# Note that the base64 string is a very long string, click on the three dot icon to the left of the current code cell and click on <code> Copy Cell Output </code> to easily copy it to your clipboard.
#
# Then, to embed the string into your Jupyter Notebook :
# ```
# from PIL import Image
# import io
# import base64
# import matplotlib.pyplot as plt
# import numpy as np
#
# # PASTE BASE64 STRING HERE
# base64_image = "iVBORw0K..."  # long base64 string
#
# img_data = base64.b64decode(base64_image)
# img = Image.open(io.BytesIO(img_data))
#
# plt.imshow(img)
# plt.axis("off")
# ```
# The string is really long so, use a multiline string in python ( syntax : """ """ )
#
# Otherwise, you can also choose to use any API ( try researching on https://picsum.photos/ )

# %% [markdown]
# ## SECTIONS 1 : Preps

# %% [markdown]
# ### Flat Image : reference as "flat"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_f = """
...

"""

img_data_f = base64.b64decode(base64_image_f)
flat = np.array(Image.open(io.BytesIO(img_data_f)))

plt.imshow(flat)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ### Edge Image : reference as "edge"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_e = """
...

"""

img_data_e = base64.b64decode(base64_image_e)
edge = np.array(Image.open(io.BytesIO(img_data_e)))

plt.imshow(edge)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ### Corner Image : reference as "corner"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_c1 = """
...

"""

img_data_c1 = base64.b64decode(base64_image_c1)
corner = np.array(Image.open(io.BytesIO(img_data_c1)))

plt.imshow(corner)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# ### Multiple Coorners : reference as "corner2"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image_c2 = """
...

"""

img_data_c2 = base64.b64decode(base64_image_c2)
corner2 = np.array(Image.open(io.BytesIO(img_data_c2)))

plt.imshow(corner2)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1499.5), np.float64(1121.5), np.float64(-0.5))

# %% [markdown]
# ### Bonus Question Image 1 : reference as "ball"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image = """
...

"""

img_data = base64.b64decode(base64_image)
ball = np.array(Image.open(io.BytesIO(img_data)))

plt.imshow(ball)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(625.5), np.float64(416.5), np.float64(-0.5))

# %% [markdown]
# ### Bonus Question Image 2 : reference as "ball2"

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

# PASTE BASE64 STRING HERE
base64_image = """
...

"""

img_data = base64.b64decode(base64_image)
ball2 = np.array(Image.open(io.BytesIO(img_data)))

plt.imshow(ball2)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(642.5), np.float64(359.5), np.float64(-0.5))

# %% [markdown]
# ## SECTION 2 : Questions

# %% [markdown]
# ### Part A - Corner Detection
#
# Pick images of your choice which you feel should give a good output. Use above ones if you cannot find any else.
# Create or pick 3 images : one flat, one edge, one corner image. Examples shown above, you are free to you them too.
# Use the sobel kernels to find Ix and Iy ( or Gx and Gy whatever you call it ) and plot them. Then, create a scatter plot for Iy vs Ix. If you threshold, mention clearly that you have along with the threshold value too. Ideally make a function that takes the image and prints the graphs, also make the function return the Iy and Ix values for further questions.
# Hint: use grayscale only.

# %%
# Your PART A codes follow here. You can create more cells under this. Write clean and commented code.

# %%
from PIL import Image
import io
import base64
import numpy as np
import matplotlib.pyplot as plt
import cv2
base64_image_f = """
...

"""

img_data_f = base64.b64decode(base64_image_f)
flat = np.array(Image.open(io.BytesIO(img_data_f)))

plt.imshow(flat)
plt.axis("off")
plt.title("Flat Image")
plt.show()

base64_image_e = """
...

"""

img_data_e = base64.b64decode(base64_image_e)
edge = np.array(Image.open(io.BytesIO(img_data_e)))

plt.imshow(edge)
plt.axis("off")
plt.title("Edge Image")
plt.show()

base64_image_c1 = """
...

"""
img_data_c1 = base64.b64decode(base64_image_c1)
corner = np.array(Image.open(io.BytesIO(img_data_c1)))

plt.imshow(corner)
plt.axis("off")
plt.title("Corner Image")
plt.show()

def sobel_analysis(img, title, threshold=None):
    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    # Sobel gradients
    Ix = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=3)
    Iy = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=3)

    # Flatten for scatter plot
    Ix_flat = Ix.flatten()
    Iy_flat = Iy.flatten()

    # Thresholding
    if threshold is not None:
        mask = (np.abs(Ix_flat) > threshold) | (np.abs(Iy_flat) > threshold)
        Ix_flat = Ix_flat[mask]
        Iy_flat = Iy_flat[mask]

    # Plot results
    plt.figure(figsize=(12,4))

    plt.subplot(1,3,1)
    plt.imshow(Ix, cmap='gray')
    plt.title(f"{title} : Ix")
    plt.axis("off")

    plt.subplot(1,3,2)
    plt.imshow(Iy, cmap='gray')
    plt.title(f"{title} : Iy")
    plt.axis("off")

    plt.subplot(1,3,3)
    plt.scatter(Ix_flat, Iy_flat, s=1)
    plt.xlabel("Ix")
    plt.ylabel("Iy")
    plt.title(f"{title} : Iy vs Ix")

    plt.tight_layout()
    plt.show()

    return Ix, Iy
# Threshold used to remove noise
THRESHOLD = 20

Ix_flat, Iy_flat = sobel_analysis(flat, "Flat Image", threshold=THRESHOLD)
Ix_edge, Iy_edge = sobel_analysis(edge, "Edge Image", threshold=THRESHOLD)
Ix_corner, Iy_corner = sobel_analysis(corner, "Corner Image", threshold=THRESHOLD)

# %% [markdown]
# ### Part B - Ellipse Fitting and R Maps for Corner Detection
#
# Now, use the above functions ( basically Ix and Iy ) and the formulas in the pre-session videos to find values of a,b and c ( the second moments ) and calculate the eigenvalues lambda1 and lambda2. Then use those to create an R map for the entire image. Display the R map. Do it for the 3 images of part A. So, you might want to create a function that takes the image, loops over the pixels with a window, fits the ellipse over the window, calculates the lambdas, and value of R, essentially finding R values for all the pixels and returning an R-map ( a 2d image with only one channel where the value of a pixel is the r-value of that pixel in the original grayscale image ). Now, display these R maps. Notice how the corners are clearly visible in white.

# %%
# Your PART B codes follow here. You can create more cells under this. Write clean and commented code.

# %%
from PIL import Image
import io, base64
import numpy as np
import matplotlib.pyplot as plt
import cv2

base64_image_f =  """
...

"""
flat = np.array(Image.open(io.BytesIO(base64.b64decode(base64_image_f))))

base64_image_e = """
...

"""
edge = np.array(Image.open(io.BytesIO(base64.b64decode(base64_image_e))))

base64_image_c1 =  """
...

"""
corner = np.array(Image.open(io.BytesIO(base64.b64decode(base64_image_c1))))

def harris_r_map(img, window_size=3, k=0.04):
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    gray = gray.astype(np.float32)

    # Sobel gradients
    Ix = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=3)
    Iy = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=3)

    # Second moment terms
    Ix2 = Ix * Ix
    Iy2 = Iy * Iy
    Ixy = Ix * Iy

    # R map
    R = np.zeros(gray.shape)

    offset = window_size // 2

    for y in range(offset, gray.shape[0] - offset):
        for x in range(offset, gray.shape[1] - offset):

            # Window sums
            a = np.sum(Ix2[y-offset:y+offset+1, x-offset:x+offset+1])
            b = np.sum(Ixy[y-offset:y+offset+1, x-offset:x+offset+1])
            c = np.sum(Iy2[y-offset:y+offset+1, x-offset:x+offset+1])

            # Harris response
            R[y, x] = (a*c - b*b) - k * (a + c)**2

    return R

##Computing R-maps for all 3 images
R_flat   = harris_r_map(flat)
R_edge   = harris_r_map(edge)
R_corner = harris_r_map(corner)

##displaying R-maps
def show_r_map(R, title):
    R_norm = cv2.normalize(R, None, 0, 255, cv2.NORM_MINMAX)
    plt.figure(figsize=(5,5))
    plt.imshow(R_norm, cmap='gray')
    plt.title(title)
    plt.axis("off")
    plt.show()

show_r_map(R_flat, "Harris R Map - Flat Image")
show_r_map(R_edge, "Harris R Map - Edge Image")
show_r_map(R_corner, "Harris R Map - Corner Image")

# %% [markdown]
# ### Part C - Hough Transforms
#
# Again, import an image, create a function that takes the image, finds the canny edge map, then loops through it to find the equivalent line of each pixel, checks whether the slope and intercept are within acceptable limits of the accumulator size ( if not, discard ), does the voting procedure and creates the accumulator. Now, choose an accurate threshold for the accumulator to get the slope and intercept for a good number of lines in the image. One thing you can do is normalise the accumulator and use a 90 percent threshold ( just an example, im not telling if 90p is a good one or not ), then, mark the lines in the image using cv2 and display the final output. For the slope and intercept, choose the limit as per your image to get a good output. Please dont make it super large so it take hours to run and give the output.
#
# Now, you can do the same but with rho theta method. Do this in a separate code cell from slope-intercept method and notice how fast this is

# %%
# Your PART C codes follow here. You can create more cells under this. Write clean and commented code.

# %%
from PIL import Image
import io, base64
import numpy as np
import matplotlib.pyplot as plt
import cv2

# EDGE IMAGE
base64_image_edge = """
...

"""

img_data = base64.b64decode(base64_image_edge)
edge_img = np.array(Image.open(io.BytesIO(img_data)))

plt.imshow(edge_img)
plt.title("Input Image for Hough Transform")
plt.axis("off")
plt.show()

# %%
def hough_slope_intercept_fixed(image,
                                m_min=-1, m_max=1, m_bins=150,
                                c_min=-300, c_max=300, c_bins=250,
                                acc_thresh_ratio=0.6,
                                top_n=10):

    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    edges = cv2.Canny(gray, 100, 200)

    h, w = edges.shape

    m_vals = np.linspace(m_min, m_max, m_bins)
    c_vals = np.linspace(c_min, c_max, c_bins)

    accumulator = np.zeros((m_bins, c_bins), dtype=np.int32)

    ys, xs = np.nonzero(edges)

    # VOTING
    for x, y in zip(xs, ys):
        for i, m in enumerate(m_vals):
            c = y - m * x
            if c_min <= c <= c_max:
                j = int((c - c_min) / (c_max - c_min) * (c_bins - 1))
                accumulator[i, j] += 1

    #NORMALISE
    acc_norm = accumulator / accumulator.max()

    #THRESHOLD
    idxs = np.where(acc_norm > acc_thresh_ratio)

    if len(idxs[0]) == 0:
        print("No lines detected — try lowering threshold")
        return edges, accumulator, image.copy()

    # PICK TOP-N STRONGEST
    votes = acc_norm[idxs]
    top_idxs = np.argsort(votes)[-top_n:]

    img_lines = image.copy()

    for t in top_idxs:
        i = idxs[0][t]
        j = idxs[1][t]

        m = m_vals[i]
        c = c_vals[j]

        x1, x2 = 0, w
        y1 = int(m * x1 + c)
        y2 = int(m * x2 + c)

        if 0 <= y1 < h and 0 <= y2 < h:
            cv2.line(img_lines, (x1, y1), (x2, y2), (0, 255, 255), 3)


    return edges, accumulator, img_lines

edges_mc, acc_mc, result_mc = hough_slope_intercept_fixed(edge_img)

plt.figure(figsize=(6,6))
plt.imshow(result_mc)
plt.title("Slope–Intercept Hough Lines")
plt.axis("off")
plt.show()

# %%
def hough_rho_theta(image,
                    theta_bins=180,
                    rho_bins=250,
                    acc_thresh_ratio=0.9):

    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    edges = cv2.Canny(gray, 100, 200)

    h, w = edges.shape
    diag = int(np.sqrt(h*h + w*w))

    thetas = np.linspace(-np.pi/2, np.pi/2, theta_bins)
    rhos = np.linspace(-diag, diag, rho_bins)

    accumulator = np.zeros((rho_bins, theta_bins), dtype=np.int32)

    ys, xs = np.nonzero(edges)

    # Voting
    for x, y in zip(xs, ys):
        for t_idx, theta in enumerate(thetas):
            rho = x*np.cos(theta) + y*np.sin(theta)
            r_idx = int((rho + diag) / (2*diag) * (rho_bins - 1))
            accumulator[r_idx, t_idx] += 1

    acc_norm = accumulator / accumulator.max()
    idxs = np.where(acc_norm > acc_thresh_ratio)

    img_lines = image.copy()

    for r_idx, t_idx in zip(idxs[0], idxs[1]):
        rho = rhos[r_idx]
        theta = thetas[t_idx]

        a, b = np.cos(theta), np.sin(theta)
        x0, y0 = a*rho, b*rho

        x1 = int(x0 + 1000*(-b))
        y1 = int(y0 + 1000*(a))
        x2 = int(x0 - 1000*(-b))
        y2 = int(y0 - 1000*(a))

        cv2.line(img_lines, (x1,y1), (x2,y2), (0,255,0), 2)

    return edges, accumulator, img_lines

edges_rt, acc_rt, result_rt = hough_rho_theta(edge_img)

plt.figure(figsize=(6,6))
plt.imshow(result_rt)
plt.title("Rho–Theta Hough Lines")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Bonus - Part D
#
# Here, what you have to do is something like :
# 1. Create a python function that will take the first image and a set of coordinates ( x1,y1 ) - top left and ( x2,y2 ) - bottom right to form a box around the white ball. Now, find gradients, select the biggest completed gradient ( maximum area contour ) and then create an RGBA ( 4 channel ) stencil.
#
# 2. Now, create another function that takes this stencil and second image and a coordinate ( x3,y3 ). Now, treat ( x3,y3 ) as center point and overlap the RGBA stencil with second image. Keep x3 y3 such that it is towards the right to make it look like that white ball is on the green pool image.
#
#
# Again, I do not expect you guys to get a really good result. Try your best though.

# %%
ball
# Out:
# array([[[ 91,  71,  46],
#         [ 91,  71,  46],
#         [ 92,  72,  47],
#         ...,
#         [ 87,  71,  58],
#         [ 86,  70,  55],
#         [ 86,  70,  55]],
#
#        [[ 90,  70,  47],
#         [ 90,  70,  47],
#         [ 90,  70,  47],
#         ...,
#         [ 86,  70,  57],
#         [ 86,  70,  55],
#         [ 86,  70,  55]],
#
#        [[ 87,  66,  45],
#         [ 87,  66,  45],
#         [ 87,  66,  45],
#         ...,
#         [ 86,  70,  57],
#         [ 86,  70,  55],
#         [ 86,  70,  55]],
#
#        ...,
#
#        [[  8,  83, 215],
#         [  8,  83, 215],
#         [  8,  83, 215],
#         ...,
#         [  7,  72, 198],
#         [  6,  71, 197],
#         [  6,  71, 197]],
#
#        [[  8,  83, 215],
#         [  8,  83, 215],
#         [  8,  83, 215],
#         ...,
#         [  7,  72, 198],
#         [  6,  71, 197],
#         [  6,  71, 197]],
#
#        [[  7,  84, 215],
#         [  7,  84, 215],
#         [  7,  84, 215],
#         ...,
#         [  7,  70, 198],
#         [  7,  70, 198],
#         [  7,  70, 198]]], dtype=uint8)

# %%
ball2
# Out:
# array([[[ 61, 166,  99],
#         [ 60, 165,  98],
#         [ 60, 165,  98],
#         ...,
#         [  6,  28,  16],
#         [  6,  28,  16],
#         [  6,  28,  16]],
#
#        [[ 61, 166,  99],
#         [ 60, 165,  98],
#         [ 60, 165,  98],
#         ...,
#         [  6,  28,  16],
#         [  6,  28,  16],
#         [  6,  28,  16]],
#
#        [[ 61, 166,  99],
#         [ 60, 165,  98],
#         [ 60, 165,  98],
#         ...,
#         [  6,  28,  16],
#         [  6,  28,  16],
#         [  6,  28,  16]],
#
#        ...,
#
#        [[ 65, 146,  79],
#         [ 65, 146,  79],
#         [ 65, 146,  80],
#         ...,
#         [ 35, 123,  62],
#         [ 35, 123,  62],
#         [ 35, 123,  62]],
#
#        [[ 65, 146,  79],
#         [ 65, 146,  79],
#         [ 65, 146,  80],
#         ...,
#         [ 35, 123,  62],
#         [ 35, 123,  62],
#         [ 35, 123,  62]],
#
#        [[ 65, 146,  79],
#         [ 65, 146,  79],
#         [ 65, 146,  80],
#         ...,
#         [ 35, 123,  62],
#         [ 35, 123,  62],
#         [ 35, 123,  62]]], dtype=uint8)

# %%
from PIL import Image
import io, base64
import numpy as np
import matplotlib.pyplot as plt
import cv2
base64_image_ball ="""
...

"""
img_data = base64.b64decode(base64_image_ball)
ball_img = np.array(Image.open(io.BytesIO(img_data)))

plt.imshow(ball_img)
plt.title("Ball1")
plt.axis("off")
plt.show()


base64_image_pool = """
...

"""


img_data2 = base64.b64decode(base64_image_pool)
ball2= np.array(Image.open(io.BytesIO(img_data2)))

plt.imshow(ball2)
plt.title("Ball2")
plt.axis("off")
plt.show()

def extract_ball_stencil(image, x1, y1, x2, y2):
    # Crop region
    crop = image[y1:y2, x1:x2]

    gray = cv2.cvtColor(crop, cv2.COLOR_RGB2GRAY)

    # Gradient magnitude
    Ix = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=3)
    Iy = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=3)
    mag = np.sqrt(Ix**2 + Iy**2)
    mag = (mag / mag.max() * 255).astype(np.uint8)

    # Threshold
    _, bw = cv2.threshold(mag, 40, 255, cv2.THRESH_BINARY)

    # Largest contour
    contours, _ = cv2.findContours(bw, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    largest = max(contours, key=cv2.contourArea)

    mask = np.zeros(gray.shape, dtype=np.uint8)
    cv2.drawContours(mask, [largest], -1, 255, -1)

    # RGBA stencil
    rgba = np.zeros((crop.shape[0], crop.shape[1], 4), dtype=np.uint8)
    rgba[..., :3] = crop
    rgba[..., 3] = mask

    return rgba


def overlay_stencil(bg, stencil, x3, y3):
    h, w = stencil.shape[:2]
    x_start = x3 - w // 2
    y_start = y3 - h // 2

    output = bg.copy()

    for i in range(h):
        for j in range(w):
            if stencil[i, j, 3] > 0:
                y = y_start + i
                x = x_start + j
                if 0 <= x < bg.shape[1] and 0 <= y < bg.shape[0]:
                    output[y, x] = stencil[i, j, :3]

    return output

# Box around ball
stencil = extract_ball_stencil(
    ball_img,
    x1=80, y1=80,
    x2=320, y2=320
)

plt.imshow(stencil[..., :3])
plt.title("RGBA Stencil (RGB view)")
plt.axis("off")
plt.show()

# Place ball slightly to the right
final_img = overlay_stencil(
    ball2,
    stencil,
    x3=ball2.shape[1] - 200,
    y3=ball2.shape[0] // 2
)

plt.imshow(final_img)
plt.title("Ball 1 Overlaid on Pool Image")
plt.axis("off")
plt.show()
